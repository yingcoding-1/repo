# %% [markdown]
# <a href="https://colab.research.google.com/github/yingcoding-1/repo/blob/main/nba_game_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
nba_df = pd.read_csv("https://raw.githubusercontent.com/WayneGretzky1/nba_game_predictor/refs/heads/main/cleaned.csv")
nba_df
# Out:
#         gameid    gamedate  home_teamid  away_teamid  home_win_avg_prev5  \
# 0     22100127  2021-11-05   1610612761   1610612739                 0.4
# 1     22100137  2021-11-06   1610612756   1610612737                 0.6
# 2     22100145  2021-11-07   1610612744   1610612745                 0.8
# 3     22100150  2021-11-08   1610612742   1610612740                 0.8
# 4     22100154  2021-11-08   1610612747   1610612766                 0.8
# ...        ...         ...          ...          ...                 ...
# 4669  22401195  2025-04-13   1610612750   1610612762                 0.8
# 4670  22401191  2025-04-13   1610612755   1610612741                 0.0
# 4671  22401200  2025-04-13   1610612758   1610612756                 0.2
# 4672  22401187  2025-04-13   1610612738   1610612766                 0.8
# 4673  22401193  2025-04-13   1610612745   1610612743                 0.8
#
#       away_win_avg_prev5  home_points_avg_prev5  away_points_avg_prev5  \
# ...

# %%
nba_df.columns
# Out:
# Index(['gameid', 'gamedate', 'home_teamid', 'away_teamid',
#        'home_win_avg_prev5', 'away_win_avg_prev5', 'home_points_avg_prev5',
#        'away_points_avg_prev5', 'home_opponent_points_avg_prev5',
#        'away_opponent_points_avg_prev5', 'home_assists_avg_prev5',
#        'away_assists_avg_prev5', 'home_blocks_avg_prev5',
#        'away_blocks_avg_prev5', 'home_steals_avg_prev5',
#        'away_steals_avg_prev5', 'home_fieldgoalsattempted_avg_prev5',
#        'away_fieldgoalsattempted_avg_prev5',
#        'home_fieldgoalspercentage_avg_prev5',
#        'away_fieldgoalspercentage_avg_prev5',
#        'home_threepointersattempted_avg_prev5',
#        'away_threepointersattempted_avg_prev5',
#        'home_threepointerspercentage_avg_prev5',
#        'away_threepointerspercentage_avg_prev5',
#        'home_freethrowsattempted_avg_prev5',
#        'away_freethrowsattempted_avg_prev5',
#        'home_freethrowspercentage_avg_prev5',
# ...

# %%
#choose features X and label y

# %%
#train-test split
from sklearn.model_selection import train_test_split

# %%
#normalize training data
from sklearn.preprocessing import StandardScaler

# %%
nba_df.loc[nba_df['gameid'] == 22400061] #first game of 2024-25 season
# Out:
#         gameid    gamedate  home_teamid  away_teamid  home_win_avg_prev5  \
# 3451  22400061  2024-10-22   1610612738   1610612752                 0.8
#
#       away_win_avg_prev5  home_points_avg_prev5  away_points_avg_prev5  \
# 3451                 0.6                  119.4                  113.4
#
#       home_opponent_points_avg_prev5  away_opponent_points_avg_prev5  ...  \
# 3451                           109.0                           110.4  ...
#
#       home_freethrowsattempted_avg_prev5  away_freethrowsattempted_avg_prev5  \
# 3451                                16.2                                19.4
#
#       home_freethrowspercentage_avg_prev5  \
# 3451                               0.7326
#
#       away_freethrowspercentage_avg_prev5  home_reboundstotal_avg_prev5  \
# 3451                               0.7856                          45.6
#
#       away_reboundstotal_avg_prev5  home_foulspersonal_avg_prev5  \
# ...
